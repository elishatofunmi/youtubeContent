# %%
import pandas as pd
import numpy as np
import sklearn as sk

# %%
from sklearn.datasets import load_iris
iris = load_iris()
X, Y = iris.data, iris.target

# %%
X.shape,Y.shape
# Out:
# ((150, 4), (150,))

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
data = pd.DataFrame(X, columns = iris.feature_names)
data.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %% [markdown]
# # **Statistics and Data Visualization**

# %%
data.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# count         150.000000        150.000000         150.000000        150.000000
# mean            5.843333          3.057333           3.758000          1.199333
# std             0.828066          0.435866           1.765298          0.762238
# min             4.300000          2.000000           1.000000          0.100000
# 25%             5.100000          2.800000           1.600000          0.300000
# 50%             5.800000          3.000000           4.350000          1.300000
# 75%             6.400000          3.300000           5.100000          1.800000
# max             7.900000          4.400000           6.900000          2.500000

# %%
import plotly

# %%
data.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)'],
#       dtype='object')

# %%
data['sepal length (cm)'][:4]
# Out:
# 0    5.1
# 1    4.9
# 2    4.7
# 3    4.6
# Name: sepal length (cm), dtype: float64

# %%
import plotly as py
import plotly.graph_objs as go
# creating trace1
trace1 =go.Scatter(
                    x = data['sepal length (cm)'], #sepal
                    y = data['petal length (cm)'], #petal
                    mode = "markers",
                    name = "sepal length (cm)",
                    marker = dict(color = 'rgba(255, 128, 255, 0.8)'),
                    text='sepal-petal length')
trace2 =go.Scatter(
                    x = data['sepal width (cm)'],
                    y = data['petal width (cm)'],
                    mode = "markers",
                    name = "sepal width (cm)",
                    marker = dict(color = 'rgba(255, 128,0, 0.8)'),
                    text= 'sepal-petal width')


datak = [trace1, trace2]
layout = dict(title = 'sepal-petal length-width visual',
              xaxis= dict(title= 'sepal',ticklen= 5,zeroline= False),
              yaxis= dict(title= 'petal',ticklen= 5,zeroline= False)
             )
fig = dict(data = datak, layout = layout)
py.io.show(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f937e7d8-5865-416d-a2ba-0c2e34a89f32" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f937e7d8-5865-416d-a2ba-0c2e34a89f32")) {
#                     Plotly.newPlot(
#                         'f937e7d8-5865-416d-a2ba-0c2e34a89f32',
# ...

# %%
import seaborn as sns
sns.pairplot(data)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning:
#
# pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.

# %%
sns.distplot(data['sepal length (cm)'])

# %%
sns.distplot(data['petal length (cm)'])

# %%
sns.distplot(data['petal width (cm)'])

# %%
sns.distplot(data['sepal width (cm)'])

# %%
sns.regplot(x = data['sepal length (cm)'], y = data['petal length (cm)'], marker = '^', color = 'red')

# %%
import plotly as py
import plotly.graph_objs as go
# create trace1 
trace0 = go.Histogram(
                x = data['sepal length (cm)'],
                name = "sepal length",
                marker = dict(color = 'rgba(255, 120, 240, 1.0)',
                             line=dict(color='rgb(0,0,0)',width=1.5)),
                text = 'sepal length')

trace1 = go.Histogram(
                x = data['sepal width (cm)'],
                name = "sepal width",
                marker = dict(color = 'rgba(25, 200, 240, 1.0)',
                             line=dict(color='rgb(0,0,0)',width=1.5)),
                text = 'sepal width')
# create trace2 
trace2 = go.Histogram(
                x = data['petal length (cm)'],
                name = "petal length",
                marker = dict(color = 'rgba(25, 255, 128, 1.0)',
                              line=dict(color='rgb(0,0,0)',width=1.5)),
                text = 'petal length')

trace3 = go.Histogram(
                x = data['petal width (cm)'],
                name = "petal width",
                marker = dict(color = 'rgba(255, 225, 50, 1.0)',
                              line=dict(color='rgb(0,0,0)',width=1.5)),
                text = 'petal width')
datak = [trace0, trace1, trace2, trace3]
layout = go.Layout(barmode = "group")
fig = go.Figure(data = datak, layout = layout)
py.io.show(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="895cf9fe-dbf7-4496-b5d1-b202519e650e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("895cf9fe-dbf7-4496-b5d1-b202519e650e")) {
#                     Plotly.newPlot(
#                         '895cf9fe-dbf7-4496-b5d1-b202519e650e',
# ...

# %% [markdown]
# # **Data Preprocessing and cleaning**

# %%
# data preparation

trace0 = go.Box(
    y=data['sepal length (cm)'],
    name = 'sepal length',
    marker = dict(
        color = 'rgb(12, 12, 140)',
    )
)
trace1 = go.Box(
    y=data['petal length (cm)'],
    name = 'petal length',
    marker = dict(
        color = 'rgb(12, 128, 128)',
    )
)


trace2 = go.Box(
    y = data['sepal width (cm)'],
    name = 'sepal width',
    marker =dict(
        color = 'rgb(12, 30,128)',
    )
)

trace3 = go.Box(
    y = data['petal width (cm)'],
    name = 'petal width',
    marker = dict(
        color = 'rgb(12,56,180)',
    )
)
datak = [trace0, trace1, trace2, trace3]
layout = go.Layout(barmode = "group")
fig = go.Figure(data = datak, layout = layout)
py.io.show(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="37239cf7-3a48-43ba-92b9-1481e960a5a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("37239cf7-3a48-43ba-92b9-1481e960a5a4")) {
#                     Plotly.newPlot(
#                         '37239cf7-3a48-43ba-92b9-1481e960a5a4',
# ...

# %%
data.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
data['sepal width (cm)'][data['sepal width (cm)']>4.0] = 4.0
data['sepal width (cm)'][data['sepal width (cm)']<2.2] = 2.2

# %%
# data preparation

trace0 = go.Box(
    y=data['sepal length (cm)'],
    name = 'sepal length',
    marker = dict(
        color = 'rgb(12, 12, 140)',
    )
)
trace1 = go.Box(
    y=data['petal length (cm)'],
    name = 'petal length',
    marker = dict(
        color = 'rgb(12, 128, 128)',
    )
)


trace2 = go.Box(
    y = data['sepal width (cm)'],
    name = 'sepal width',
    marker =dict(
        color = 'rgb(12, 30,128)',
    )
)

trace3 = go.Box(
    y = data['petal width (cm)'],
    name = 'petal width',
    marker = dict(
        color = 'rgb(12,56,180)',
    )
)
datak = [trace0, trace1, trace2, trace3]
layout = go.Layout(barmode = "group")
fig = go.Figure(data = datak, layout = layout)
py.io.show(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="13445848-f5cb-4997-84d8-ccc80c03dc92" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("13445848-f5cb-4997-84d8-ccc80c03dc92")) {
#                     Plotly.newPlot(
#                         '13445848-f5cb-4997-84d8-ccc80c03dc92',
# ...

# %% [markdown]
# #**modelling**

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data, Y, test_size = 0.2, random_state = 42, stratify = Y)
x_train.shape, y_train.shape
# Out:
# ((120, 4), (120,))

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train, y_train)
train_accuracy = lr.score(x_train, y_train)
print('train accuracy is: ', train_accuracy)
# Out:
# train accuracy is:  0.975

# %%
pred = lr.predict(x_test)
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, classification_report
test_accuracy = accuracy_score(y_test, pred)
print('test accuracy is: %.3f'%(test_accuracy))
# Out:
# test accuracy is: 0.967

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      0.90      0.95        10
#            2       0.91      1.00      0.95        10
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.97      0.97        30
# weighted avg       0.97      0.97      0.97        30

# %%
confusion_matrix(y_test, pred)
# Out:
# array([[10,  0,  0],
#        [ 0,  9,  1],
#        [ 0,  0, 10]])
